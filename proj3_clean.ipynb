# %%
#import csv
import pandas as pd
#import sqlite3
#import csv
#import codecs
#import pprint
#import re
#import xml.etree.cElementTree as ET
#import cerberus
#import schema

# %%
#nodes = pd.read_csv("nodes.csv")
nodes_tags = pd.read_csv("nodes_tags.csv")
#ways = pd.read_csv('ways.csv')
#ways_nodes = pd.read_csv("ways_nodes.csv")
ways_tags = pd.read_csv("ways_tags.csv")

# %% [markdown]
# # Download OpenStreemMap XML file to local file using web api overpass-api.de query form.

# %%
"""from data.py
This will extract fields from the OpenStreetMap XML file and store various field values in ways and nodes CSV files.
Parsing of field values includig ':' and separately problem characters (not a-z,:) is done.  The field vlaues that are 
extracted are included in the 'NODE_FIELDS','NODE_TAGS_PATH','WAYS_PATH','WAY_NODES_PATH','WAY_TAGS_PATH' lists.  The 
schema is validated as well.

A small subset of the data was validated with the provided function and then validation set to False for larger data set.
"""

OSM_PATH = "Phx_metro.osm"

NODES_PATH = "nodes.csv"
NODE_TAGS_PATH = "nodes_tags.csv"
WAYS_PATH = "ways.csv"
WAY_NODES_PATH = "ways_nodes.csv"
WAY_TAGS_PATH = "ways_tags.csv"

LOWER_COLON = re.compile(r'^([a-z]|_)+:([a-z]|_)+')
PROBLEMCHARS = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

SCHEMA = schema.schema

# Make sure the fields order in the csvs matches the column order in the sql table schema
NODE_FIELDS = ['id', 'lat', 'lon', 'user', 'uid', 'version', 'changeset', 'timestamp']
NODE_TAGS_FIELDS = ['id', 'key', 'value', 'type']
WAY_FIELDS = ['id', 'user', 'uid', 'version', 'changeset', 'timestamp']
WAY_TAGS_FIELDS = ['id', 'key', 'value', 'type']
WAY_NODES_FIELDS = ['id', 'node_id', 'position']


def shape_element(element, node_attr_fields=NODE_FIELDS, way_attr_fields=WAY_FIELDS,
                  problem_chars=PROBLEMCHARS, default_tag_type='regular'):
    """Clean and shape node or way XML element to Python dict"""

    node_attribs = {}
    way_attribs = {}
    way_nodes = []
    tags = []  # Handle secondary tags the same way for both node and way elements
    

    if element.tag == 'node':
        #build top level node_attributes
        for att in NODE_FIELDS:
            node_attribs[att] = element.attrib[att]
        
        #build node_tags
        position = 0
        for child in element:
            if child.tag == 'tag':
                tag = {}
                tag['id'] = element.attrib['id']
                #parse k attrib with a colon or two
                if bool(LOWER_COLON.search(child.attrib['k'])):
                    k = child.attrib['k'].split(':')
                    if len(k) == 3:
                        tag['key']=k[1]+':'+k[2]
                    elif len(k) == 2:
                        tag['key'] = k[1]
                    tag['type']= k[0]
                    tag['value'] = child.attrib['v'] 
                    
                elif not bool(PROBLEMCHARS.search(child.attrib['k'])):
                    tag['type'] = 'regular'
                    tag['value']=child.attrib['v']
                    tag['id'] = element.attrib['id']
                    tag['key'] = child.attrib['k']
            
                tags.append(tag)
        return {'node': node_attribs, 'node_tags' : tags}
                
    elif element.tag == 'way':
        #build top level way_attribs
        for att in WAY_FIELDS:
            way_attribs[att] = element.attrib[att]
        
        #build way_tags
        position = 0
        for child in element:
            if child.tag == 'tag':
                tag = {}
                tag['id'] = element.attrib['id']
                #parse k attrib with a colon or two
                if bool(LOWER_COLON.search(child.attrib['k'])):
                    k = child.attrib['k'].split(':')
                    if len(k) == 3:
                        tag['key']=k[1]+':'+k[2]
                    elif len(k) == 2:
                        tag['key'] = k[1]
                    tag['type']= k[0]
                    tag['value'] = child.attrib['v'] 
                    
                elif not bool(PROBLEMCHARS.search(child.attrib['k'])):
                    tag['type'] = 'regular'
                    tag['value']=child.attrib['v']
                    tag['id'] = element.attrib['id']
                    tag['key'] = child.attrib['k']
            
                tags.append(tag)
            
            if child.tag == 'nd':
                nodes = {}
                nodes['id'] = element.attrib['id']
                nodes['node_id'] = child.attrib['ref']
                nodes['position'] = position
                position += 1
                way_nodes.append(nodes)
            
        return {'way': way_attribs, 'way_nodes': way_nodes, 'way_tags': tags}


# ================================================== #
#               Helper Functions                     #
# ================================================== #
def get_element(osm_file, tags=('node', 'way', 'relation')):
    """Yield element if it is the right type of tag"""

    context = ET.iterparse(osm_file, events=('start', 'end'))
    _, root = next(context)
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()


def validate_element(element, validator, schema=SCHEMA):
    """Raise ValidationError if element does not match schema"""
    if validator.validate(element, schema) is not True:
        field, errors = next(validator.errors.iteritems())
        message_string = "\nElement of type '{0}' has the following errors:\n{1}"
        error_string = pprint.pformat(errors)
        
        raise Exception(message_string.format(field, error_string))


class UnicodeDictWriter(csv.DictWriter, object):
    """Extend csv.DictWriter to handle Unicode input"""

    def writerow(self, row):
        super(UnicodeDictWriter, self).writerow({
            k: (v.encode('utf-8') if isinstance(v, unicode) else v) for k, v in row.iteritems()
        })

    def writerows(self, rows):
        for row in rows:
            self.writerow(row)


# ================================================== #
#               Main Function                        #
# ================================================== #
def process_map(file_in, validate):
    """Iteratively process each XML element and write to csv(s)"""

    with codecs.open(NODES_PATH, 'w') as nodes_file, \
         codecs.open(NODE_TAGS_PATH, 'w') as nodes_tags_file, \
         codecs.open(WAYS_PATH, 'w') as ways_file, \
         codecs.open(WAY_NODES_PATH, 'w') as way_nodes_file, \
         codecs.open(WAY_TAGS_PATH, 'w') as way_tags_file:

        nodes_writer = UnicodeDictWriter(nodes_file, NODE_FIELDS)
        node_tags_writer = UnicodeDictWriter(nodes_tags_file, NODE_TAGS_FIELDS)
        ways_writer = UnicodeDictWriter(ways_file, WAY_FIELDS)
        way_nodes_writer = UnicodeDictWriter(way_nodes_file, WAY_NODES_FIELDS)
        way_tags_writer = UnicodeDictWriter(way_tags_file, WAY_TAGS_FIELDS)

        nodes_writer.writeheader()
        node_tags_writer.writeheader()
        ways_writer.writeheader()
        way_nodes_writer.writeheader()
        way_tags_writer.writeheader()

        validator = cerberus.Validator()

        for element in get_element(file_in, tags=('node', 'way')):
            el = shape_element(element)
            if el:
                if validate is True:
                    validate_element(el, validator)

                if element.tag == 'node':
                    nodes_writer.writerow(el['node'])
                    node_tags_writer.writerows(el['node_tags'])
                elif element.tag == 'way':
                    ways_writer.writerow(el['way'])
                    way_nodes_writer.writerows(el['way_nodes'])
                    way_tags_writer.writerows(el['way_tags'])


if __name__ == '__main__':
    # Note: Validation is ~ 10X slower. For the project consider using a small
    # sample of the map when validating.
    process_map(OSM_PATH, validate=False)

# %%
def db_table_from_csv(db_name, file_name, table_name, keys = [], key_params = []):
    '''file_name: name of csv file, 
    table: name of table to create in db_name, 
    keys: columsn of .csv file_name to include in db table
    key_params: parameters for data type for each field in table'''

    con = sqlite3.connect(db_name)
    cur = con.cursor()

    #Creation of nodes ways table
    cur.execute("DROP TABLE IF EXISTS " + table_name + ";")
    con.commit()
    
    create_str = "" #holds schema string to pass to sql
    for i in range(len(keys)):
        create_str = create_str + keys[i] + " " + key_params[i]+","
    create_str = create_str[:-1]
    cur.execute("CREATE TABLE " + table_name + "("+create_str+");")

    con.commit()
    with open(file_name, 'rb') as fin:
        dr = csv.DictReader(fin)
        to_db = [[i[key].decode("utf-8") for key in keys] for i in dr]
    
    key_str = ""
    key_qs = ""
    for key in keys:
        key_str = key_str+key+","
        key_qs = key_qs + "?," #just how many fields to enter into db
    key_qs = key_qs[:-1] #strip comma at end
    key_str=key_str[:-1]
    
    #insert data into db according to keys
    cur.executemany("INSERT INTO "+table_name+"("+key_str+") VALUES ("+key_qs+");", to_db)
    con.commit()

    con.close()
    return

# %%
DB_NAME = 'Phx_metro.db'
NODE_FIELDS = ['id', 'lat', 'lon', 'user', 'uid', 'version', 'changeset', 'timestamp']
NODE_TAGS_FIELDS = ['id', 'key', 'value', 'type']
WAY_FIELDS = ['id', 'user', 'uid', 'version', 'changeset', 'timestamp']
WAY_TAGS_FIELDS = ['id', 'key', 'value', 'type']
WAY_NODES_FIELDS = ['id', 'node_id', 'position']

NODE_PARAMS = ['INTEGER PRIMARY KEY NOT NULL', 'REAL', 'REAL', 'TEXT', 'INTEGER', 'TEXT', 'INTEGER', 'DATE']
NODE_TAGS_PARAMS = ['INTEGER NOT NULL', 'TEXT NOT NULL', 'TEXT NOT NULL', 'TEXT NOT NULL']
WAY_PARAMS = ['INTEGER NOT NULL', 'TEXT NOT NULL', 'INTEGER NOT NULL', 'TEXT NOT NULL', 'INTEGER NOT NULL', 'TEXT NOT NULL']
WAY_NODES_PARAMS = ['INTEGER NOT NULL', 'INTEGER NOT NULL', 'INTEGER NOT NULL']
WAY_TAGS_PARAMS = ['INTEGER NOT NULL', 'TEXT NOT NULL', 'TEXT NOT NULL', 'TEXT NOT NULL']


db_table_from_csv(DB_NAME, 'nodes.csv', 'nodes', NODE_FIELDS, NODE_PARAMS)
db_table_from_csv(DB_NAME, 'nodes_tags.csv', 'nodes_tags', NODE_TAGS_FIELDS, NODE_TAGS_PARAMS)
db_table_from_csv(DB_NAME, 'ways.csv', 'ways', WAY_FIELDS, WAY_PARAMS)
db_table_from_csv(DB_NAME, 'ways_tags.csv', 'way_tags', WAY_TAGS_FIELDS, WAY_TAGS_PARAMS)
db_table_from_csv(DB_NAME, 'ways_nodes.csv', 'way_nodes', WAY_NODES_FIELDS, WAY_NODES_PARAMS)

# %% [markdown]
# #### Cities list from http://phoenix.about.com/od/govtcity/qt/cities-towns-maricopa-county.htm

# %%
cities = ['Apache Junction','Avondale','Buckeye','Carefree','Cave Creek','Chandler','El Mirage','Fountain Hills',
          'Gila Bend','Gilbert','Glendale','Goodyear','Guadalupe','Litchfield Park','Mesa','Paradise Valley',
          'Peoria','Phoenix','Queen Creek','Scottsdale','Surprise','Tempe','Tolleson','Wickenburg','Youngtown']

# %% [markdown]
# ## As a measure, just check to see how close the word distance is among city/town names themselves.

# %%
for i in range(len(cities)):
    print(cities[i],best_match(cities[i],cities[:i]))
# Out:
# ('Apache Junction', ('', 0))
# ('Avondale', ('Apache Junction', 0.2608695652173913))
# ('Buckeye', ('Apache Junction', 0.18181818181818182))
# ('Carefree', ('Buckeye', 0.4))
# ('Cave Creek', ('Carefree', 0.6666666666666666))
# ('Chandler', ('Avondale', 0.625))
# ('El Mirage', ('Cave Creek', 0.42105263157894735))
# ('Fountain Hills', ('Avondale', 0.36363636363636365))
# ('Gila Bend', ('Avondale', 0.35294117647058826))
# ('Gilbert', ('Gila Bend', 0.625))
# ('Glendale', ('Avondale', 0.625))
# ('Goodyear', ('Gilbert', 0.4))
# ('Guadalupe', ('Avondale', 0.5882352941176471))
# ('Litchfield Park', ('Cave Creek', 0.4))
# ('Mesa', ('Glendale', 0.3333333333333333))
# ('Paradise Valley', ('Avondale', 0.43478260869565216))
# ('Peoria', ('El Mirage', 0.4))
# ('Phoenix', ('Peoria', 0.46153846153846156))
# ('Queen Creek', ('Cave Creek', 0.6666666666666666))
# ('Scottsdale', ('Avondale', 0.5555555555555556))
# ('Surprise', ('Peoria', 0.42857142857142855))
# ('Tempe', ('El Mirage', 0.42857142857142855))
# ('Tolleson', ('Phoenix', 0.4))
# ('Wickenburg', ('Buckeye', 0.35294117647058826))
# ('Youngtown', ('Fountain Hills', 0.43478260869565216))

# %%
def best_match(text, match_list, case = False):
    from difflib import SequenceMatcher
    max_match = 0
    max_pos = 0
    best_match = ''
    for compare in match_list:
        if case == False:
            match_score = SequenceMatcher(None, text.lower(), compare.lower()).ratio()
        elif case == True:
            match_score = SequenceMatcher(None, text, compare).ratio()
        if match_score > max_match:
            max_match = match_score
            best_match = compare
        else:
            continue
    max_score = max_match
    return (best_match, max_score)

# %% [markdown]
# ## Testing and implementing the best_match function on the csv data

# %%
for city_name in city_data_vals:
    match,score = best_match(city_name, cities)
    if score > 0.6:
        print("Match {} to {}".format(city_name, match))
    else:
        print("No match found for {}".format(city_name))
# Out:
# Match El Mirage to El Mirage
# Match Glemdale to Glendale
# Match Phenix to Phoenix
# No match found for Fort McDowell
# Match Golbert to Gilbert
# Match Carefree to Carefree
# Match Litchfield Park to Litchfield Park
# No match found for Morristown
# Match Surprise to Surprise
# Match Gilbert to Gilbert
# No match found for Mayer
# Match Goodyear to Goodyear
# Match Chandler to Chandler
# Match Msa to Mesa
# No match found for Higley
# No match found for Rio Verde
# Match Phoenx to Phoenix
# Match tempe to Tempe
# Match Tempe to Tempe
# No match found for Luke AFB, Waddell
# No match found for Laveen Village
# Match Peoria to Peoria
# Match Apache Junction to Apache Junction
# Match Scottsdale to Scottsdale
# No match found for Sun City West
# Match Queen Creek to Queen Creek
# No match found for Sun Lakes
# Match Avondale to Avondale
# No match found for sun City West
# Match Fountain Hills to Fountain Hills
# No match found for Luke AFB
# No match found for Laveen
# Match tEMPE to Tempe
# Match peoria to Peoria
# Match Paradise Valley, AZ to Paradise Valley
# Match Paradise Valley to Paradise Valley
# No match found for Gold Canyon
# Match Glendale to Glendale
# No match found for Superstition Mountain
# Match Tollenson to Tolleson
# Match Mesa to Mesa
# Match Phoenix, AZ to Phoenix
# Match Phoenix to Phoenix
# No match found for Sun City
# Match Tolleson to Tolleson
# Match Cave Creek to Cave Creek
# No match found for San Tan Valley
# Match Buckeye to Buckeye
# Match CHANDLER to Chandler
# Match Queen Valley to Queen Creek

# %% [markdown]
# ## Now to run the csv data and send out to files

# %%
unmatched = []
for i in range(len(ways_tags)):
    if ways_tags['key'][i] == 'city':
        match, score = best_match(ways_tags['value'][i], cities, case=False)
        if score > 0.6:
            ways_tags.loc[i,'value'] = match
        else:
            unmatched.append(ways_tags['value'][i])
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000
# 60000
# 61000
# 62000
# 63000
# 64000
# 65000
# 66000
# 67000
# 68000
# 69000
# 70000
# 71000
# 72000
# 73000
# 74000
# 75000
# 76000
# 77000
# 78000
# 79000
# 80000
# 81000
# 82000
# 83000
# 84000
# 85000
# 86000
# 87000
# 88000
# 89000
# 90000
# 91000
# 92000
# 93000
# 94000
# 95000
# 96000
# 97000
# 98000
# 99000
# 100000
# 101000
# 102000
# 103000
# 104000
# 105000
# 106000
# 107000
# 108000
# 109000
# 110000
# 111000
# 112000
# 113000
# 114000
# 115000
# 116000
# 117000
# 118000
# 119000
# 120000
# 121000
# 122000
# 123000
# 124000
# 125000
# 126000
# 127000
# 128000
# 129000
# 130000
# 131000
# 132000
# 133000
# 134000
# 135000
# 136000
# 137000
# 138000
# 139000
# 140000
# 141000
# 142000
# 143000
# 144000
# 145000
# 146000
# 147000
# 148000
# 149000
# 150000
# 151000
# 152000
# 153000
# 154000
# 155000
# 156000
# 157000
# 158000
# 159000
# 160000
# 161000
# 162000
# 163000
# 164000
# 165000
# 166000
# 167000
# 168000
# 169000
# 170000
# 171000
# 172000
# 173000
# 174000
# 175000
# 176000
# 177000
# 178000
# 179000
# 180000
# 181000
# 182000
# 183000
# 184000
# 185000
# 186000
# 187000
# 188000
# 189000
# 1610000
# 1611000
# 1612000
# 1613000
# 1614000
# 1615000
# 1616000
# 1617000
# 1618000
# 1619000
# 1620000
# 1621000
# 1622000
# 1623000
# 1624000
# 1625000
# 1626000
# 1627000
# 1628000
# 1629000
# 1630000
# 1631000
# 1632000
# 1633000
# 1634000
# 1635000
# 1636000
# 1637000
# 1638000
# 1639000
# 1640000
# 1641000
# 1642000
# 1643000
# 1644000
# 1645000
# 1646000
# 1647000
# 1648000
# 1649000
# 1650000
# 1651000
# 1652000
# 1653000
# 1654000
# 1655000
# 1656000
# 1657000
# 1658000
# 1659000
# 1660000
# 1661000
# 1662000
# 1663000
# 1664000
# 1665000
# 1666000
# 1667000
# 1668000
# 1669000
# 1670000
# 1671000
# 1672000
# 1673000
# 1674000
# 1675000
# 1676000
# 1677000
# 1678000
# 1679000
# 1680000
# 1681000
# 1682000
# 1683000
# 1684000
# 1685000
# 1686000
# 1687000
# 1688000
# 1689000
# 1690000
# 1691000
# 1692000
# 1693000
# 1694000
# 1695000
# 1696000
# 1697000
# 1698000
# 1699000
# 1700000
# 1701000
# 1702000
# 1703000
# 1704000
# 1705000
# 1706000
# 1707000
# 1708000
# 1709000
# 1710000
# 1711000
# 1712000
# 1713000
# 1714000
# 1715000
# 1716000
# 1717000
# 1718000
# 1719000
# 1720000
# 1721000
# 1722000
# 1723000
# 1724000
# 1725000
# 1726000
# 1727000
# 1728000
# 1729000
# 1730000
# 1731000

# %%
set(unmatched)
# Out:
# {'2036 N. Gilbert Rd.',
#  'Gold Canyon',
#  'Laveen',
#  'Laveen Village',
#  'Maricopa',
#  'Riverside',
#  'San Diego',
#  'San Tan Valley',
#  'Sun City',
#  'Sun City West',
#  'Tohono Oodham',
#  'Wittmann'}

# %%
unmatched = []
for i in range(len(nodes_tags)):
    if nodes_tags['key'][i] == 'city':
        match, score = best_match(nodes_tags['value'][i], cities, case=False)
        if score > 0.6:
            nodes_tags.loc[i,'value'] = match
        else:
            unmatched.append(nodes_tags['value'][i])
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000
# 60000
# 61000
# 62000
# 63000
# 64000
# 65000
# 66000
# 67000
# 68000
# 69000
# 70000
# 71000
# 72000
# 73000
# 74000
# 75000
# 76000
# 77000
# 78000
# 79000
# 80000
# 81000
# 82000
# 83000
# 84000
# 85000
# 86000
# 87000
# 88000
# 89000
# 90000
# 91000
# 92000
# 93000
# 94000
# 95000
# 96000
# 97000
# 98000
# 99000
# 100000
# 101000
# 102000
# 103000
# 104000
# 105000
# 106000
# 107000
# 108000
# 109000
# 110000
# 111000
# 112000
# 113000
# 114000
# 115000
# 116000
# 117000
# 118000
# 119000
# 120000
# 121000
# 122000
# 123000
# 124000
# 125000
# 126000
# 127000
# 128000
# 129000
# 130000
# 131000
# 132000
# 133000
# 134000
# 135000
# 136000
# 137000
# 138000
# 139000
# 140000
# 141000
# 142000
# 143000
# 144000
# 145000
# 146000
# 147000
# 148000
# 149000
# 150000
# 151000
# 152000
# 153000
# 154000
# 155000
# 156000
# 157000
# 158000
# 159000
# 160000
# 161000
# 162000
# 163000
# 164000
# 165000
# 166000
# 167000
# 168000
# 169000
# 170000
# 171000
# 172000
# 173000
# 174000
# 175000
# 176000
# 177000
# 178000
# 179000
# 180000
# 181000
# 182000
# 183000
# 184000
# 185000
# 186000
# 187000
# 188000
# 189000
# 190000
# 191000
# 192000
# 193000
# 194000
# 195000
# 196000
# 197000
# 198000
# 199000
# 200000
# 201000
# 202000
# 203000
# 204000
# 205000
# 206000
# 207000
# 208000
# 209000
# 210000
# 211000
# 212000
# 213000
# 214000
# 215000
# 216000
# 217000
# 218000
# 219000
# 220000
# 221000
# 222000
# 223000
# 224000
# 225000
# 226000
# 227000
# 228000
# 229000
# 230000
# 231000
# 232000
# 233000
# 234000
# 235000
# 236000
# 237000
# 238000
# 239000
# 240000
# 241000
# 242000
# 243000
# 244000
# 245000
# 246000
# 247000
# 248000
# 249000
# 250000
# 251000
# 252000
# 253000
# 254000
# 255000
# 256000
# 257000
# 258000
# 259000
# 260000
# 261000
# 262000
# 263000
# 264000
# 265000
# 266000
# 267000
# 268000
# 269000
# 270000
# 271000
# 272000
# 273000
# 274000
# 275000
# 276000
# 277000
# 278000
# 279000
# 280000

# %%
ways_tags[ways_tags['value'] == "San Diego"]
# Out:
#         Unnamed: 0  Unnamed: 0.1       id        key      value   type
# 198777      198777        198777  5618435  name_base  San Diego  tiger

# %% [markdown]
# # Now manipulate the 'Street' vs 'St' type inconsistencies

# %%
#Just checking to see what types of values there are to be fixed.
set(ways_tags[ways_tags['key'] == 'street']['value'])
# Out:
# {'17054 W Post D',
#  '19th Avenue',
#  '22nd Place',
#  '40th Street',
#  '5810 Alameda Rd.',
#  'Adobe Street',
#  'Allred Avenue',
#  'Apache Blvd.',
#  'Banner Gateway Drive',
#  'Boston Street',
#  'Brown Road',
#  'Des Moines Street',
#  'E Golden Eagle Blvd',
#  'E Lynx Place',
#  'E Rittenhouse Road',
#  'E Stanford Drive',
#  'E Terrace Ave',
#  'E Warner Rd',
#  'E. Davenport Dr.',
#  'E. Devonshire Ave.',
#  'E. Divot Drive',
#  'E. Eagle Crest Drive',
#  'E. Elliot Rd',
#  'E. Frontier St',
#  'E. Longbow Parkway',
#  'E. Pima Road',
#  'East 10th Street',
#  'East 12th Avenue',
#  'East 16th Avenue',
#  'East 17th Avenue',
#  'East 18th Avenue',
#  'East 1st Avenue',
#  'East 1st Street',
#  'East 29th Avenue',
#  'East 2nd Street',
#  'East 34th Avenue',
#  'East 36th Avenue',
#  'East 38th Avenue',
#  'East 39th Avenue',
#  'East 4th Avenue',
#  'East 4th Street',
#  'East 5th Street',
#  'East 6th Place',
#  'East 6th Street',
#  'East 7th Street',
#  'East 8th Street',
#  'East 9th Place',
#  'East Adams Street',
#  'East Adobe Road',
#  'East Adobe Street',
#  'East Alameda Drive',
#  'East Apache Boulevard',
#  'East Apache Trail',
#  'East Auto Center Drive',
#  'East Avenue of the Fountains',
#  'East Baseline Avenue',
#  'East Baseline Road',
#  'East Baywood Avenue',
#  'East Beardsley Road',
#  'East Bell Road',
#  'East Bella Vista Road',
#  'East Belmont Avenue',
#  'East Bethany Home Road',
#  'East Billings Street',
#  'East Bloomfield Road',
#  'East Boise Street',
#  'East Boulder Drive',
#  'East Brill Street',
#  'East Brinker Drive',
#  'East Broadway Avenue',
#  'East Broadway Road',
#  'East Brown Road',
#  'East Buchanan Street',
#  'East Buckeye Road',
#  'East Cactus Road',
#  'East Camelback Road',
#  'East Cave Creek Road',
#  'East Chandler Boulevard',
#  'East Chandler Heights Road',
#  'East Chaparral Road',
#  'East Chauncey Lane',
#  'East Chicago Street',
#  'East Christy Drive',
#  'East Clarendon Avenue',
#  'East Club Village Drive',
#  'East Coconino Drive',
#  'East Coralbell Avenue',
#  'East Coronado Road',
#  'East Culver Street',
#  'East Desert Cove Avenue',
#  'East Desert Sky Court',
#  'East Desert Vista Trail',
#  'East Devonshire Avenue',
#  'East Devonshire Court',
#  'East Diamond Court',
#  'East Diamond Road',
#  'East Dryhead Road',
#  'East Dunlap Avenue',
#  'East Earll Drive',
#  'East El Lago Drive',
#  'East Elliot Road',
#  'East Enid Avenue',
#  'East Esplanade Avenue',
#  'East Eugie Avenue',
#  'East Exeter Boulevard',
#  'East Fairmount Avenue',
#  'East Flower Street',
#  'East Frank Lloyd Wright Boulevard',
#  'East Fruitvale Avenue',
#  'East Fruitvale Court',
#  'East Gail Road',
#  'East Gammage Park',
#  'East Garfield Street',
#  'East Gary Road',
#  'East German Road',
#  'East Germann Road',
#  'East Glacier Drive',
#  'East Glade Avenue',
#  'East Glendale Avenue',
#  'East Golf Avenue',
#  'East Greenway Parkway',
#  'East Greenway Road',
#  'East Guadalupe Road',
#  'East Hatcher Drive',
#  'East Helm Drive',
#  'East Hermosa Vista Drive',
#  'East Hilton Avenue',
#  'East Indian Bend',
#  'East Indian Bend Road',
#  'East Indian School Road',
#  'East Indianola Avenue',
#  'East Ingram Street',
#  'East Irma Lane',
#  'East Ironhorse Road',
#  'East Jackson Street',
#  'East Jefferson Street',
#  'East Kaibab Drive',
#  'East Kimball Court',
#  'East Kimball Road',
#  'East Kiwanis Drive',
#  'East Lamar Road',
#  'East Latham Court',
#  'East Latham Way',
#  'East Laurel Avenue',
#  'East Laurel Lane',
#  'East Lemon Street',
#  'East Lincoln Drive',
#  'East Lindner Avenue',
#  'East Lobster Trap Lane',
#  'East Lone Cactus Drive',
#  'East Lost Dutchman Boulevard',
#  'East Lynwood Street',
#  'East Madison Street',
#  'East Main Street',
#  'East Malapai Drive',
#  'East Marconi Avenue',
#  'East Marriott Drive',
#  'East Maryland Avenue',
#  'East Mateo Circle',
#  'East Mayo Boulevard',
#  'East McArthur Drive',
#  'East McDonald Drive',
#  'East McDowell Road',
#  'East McKellips Road',
#  'East McLellan Boulevard',
#  'East McLellan Road',
#  'East Medina Avenue',
#  'East Mercer Lane',
#  'East Mercury Drive',
#  'East Mission Lane',
#  'East Missouri Avenue',
#  'East Mohave Street',
#  'East Monroe Street',
#  'East Monte Vista Road',
#  'East Monterey Avenue',
#  'East Moreland Street',
#  'East Mountain View Road',
#  'East Myrtle Avenue',
#  'East Neville Avenue',
#  'East Northern Avenue',
#  'East Nothern Avenue',
#  'East Oak Street',
#  'East Ocotillo Road',
#  'East Old West Highway',
#  'East Onyx Avenue',
#  'East Orange Blossom Lane',
#  'East Orange Mall',
#  'East Orange Street',
#  'East Osborn Road',
#  'East Palisades Boulevard',
#  'East Palm Lane',
#  'East Paradise Drive',
#  'East Paradise Lane',
#  'East Paradise Village Parkway North',
#  'East Pima Center Parkway',
#  'East Pinchot Avenue',
#  'East Pleast Drive',
#  'East Portland Street',
#  'East Princess Drive',
#  'East Pueblo Avenue',
#  'East Purdue Avenue',
#  'East Quarterline Road',
#  'East Queen Creek Road',
#  'East Raftriver Street',
#  'East Ray Road',
#  'East Riggs Road',
#  'East Rio Salado Parkway',
#  'East Rio Salado Pkwy',
#  'East Rittenhouse Road',
#  'East Roosevelt Street',
#  'East Rose Garden Lane',
#  'East Rose Lane',
#  "East Saint Andrew's Boulevard",
#  'East Salter Drive',
#  'East San Salvador Drive',
#  'East San Tan Boulevard',
#  'East Scenic Street',
#  'East Sharon Drive',
#  'East Shea Boulevard',
#  'East Sheffield Avenue',
#  'East Sheridan Street',
#  'East Sky Harbor Circle South',
#  'East Smokehouse Trail',
#  'East Sonoran Desert Drive',
#  'East Southern Avenue',
#  'East Sunland Avenue',
#  'East Sunnyside Drive',
#  'East Superstition Boulevard',
#  'East Teton Circle',
#  'East Thomas Road',
#  'East Thunderbird Road',
#  'East Thunderbird Trail',
#  'East Tierra Buena Lane',
#  'East Timberline Drive',
#  'East Timberline Road',
#  'East Toh Vee Circle',
#  'East Tuckey Lane',
#  'East Turquoise Avenue',
#  'East Tyler Mall',
#  'East Union Hills Drive',
#  'East University Drive',
#  'East Van Buren Street',
#  'East Vernon Avenue',
#  'East Via Linda',
#  'East Via de Ventura',
#  'East Vogel Avenue',
#  'East Wagoner Road',
#  'East Warner Road',
#  'East Washington Street',
#  'East Wateka Court',
#  'East Westbrooke Road',
#  'East Willetta Street',
#  'East Williams Field Road',
#  'East Williamsfield Rd',
#  'East Windrose Drive',
#  'East Wingspan Way',
#  'East Wolf Canyon Street',
#  'East Yorkshire Circle',
#  'Fighter Country Avenue',
#  'Gainey Club Drive',
#  'Gilbert Road',
#  'Golf Club Drive',
#  'Grand Avenue',
#  'Grand Avenue #101',
#  'Leisure World Boulevard',
#  'Lindgren Avenue',
#  'Lindsay Road',
#  'Lyn Rae Drive',
#  'Main Street',
#  'N Del Cambre Ave',
#  'N Usery Pass Road',
#  'N. 120th St.',
#  'N. 77th Drive',
#  'N. 85th Street #350',
#  'N. Encanterra Drive',
#  'N. Fountain Hills Blvd',
#  'North 102nd Way',
#  'North 105th Avenue',
#  'North 105th Lane',
#  'North 106th Avenue',
#  'North 107th Avenue',
#  'North 10th Avenue',
#  'North 10th Drive',
#  'North 113th Avenue',
#  'North 114th Street',
#  'North 11th Avenue',
#  'North 124th Street',
#  'North 128th Avenue',
#  'North 128th Street',
#  'North 12th Street',
#  'North 13th Avenue',
#  'North 14th Avenue',
#  'North 14th Drive',
#  'North 14th Street',
#  'North 151st Avenue',
#  'North 15th Avenue',
#  'North 15th Drive',
#  'North 15th Place',
#  'North 15th Street',
#  'North 163rd Avenue',
#  'North 16th Avenue',
#  'North 16th Drive',
#  'North 16th Lane',
#  'North 16th Street',
#  'North 17th Avenue',
#  'North 17th Drive',
#  'North 17th Place',
#  'North 17th Street',
#  'North 18th Avenue',
#  'North 18th Drive',
#  'North 18th Street',
#  'North 19th Avenue',
#  'North 19th Street',
#  'North 1st Avenue',
#  'North 1st Drive',
#  'North 1st Street',
#  'North 20th Avenue',
#  'North 20th Street',
#  'North 21st Avenue',
#  'North 22nd Avenue',
#  'North 22nd Place',
#  'North 22nd Street',
#  'North 23rd Avenue',
#  'North 23rd Street',
#  'North 24th Avenue',
#  'North 24th Street',
#  'North 25th Avenue',
#  'North 25th Place',
#  'North 26th Avenue',
#  'North 27th Avenue',
#  'North 28th Drive',
#  'North 29th Avenue',
#  'North 29th Street',
#  'North 2nd Avenue',
#  'North 2nd Street',
#  'North 30th Street',
#  'North 31st Drive',
#  'North 32nd Avenue',
#  'North 32nd Street',
#  'North 32nd Way',
#  'North 33rd Avenue',
#  'North 35th Avenue',
#  'North 35th Street',
#  'North 37th Avenue',
#  'North 39th Avenue',
#  'North 3rd Avenue',
#  'North 3rd Street',
#  'North 40th Street',
#  'North 43rd Avenue',
#  'North 43rd Street',
#  'North 43rd Way',
#  'North 44th Street',
#  'North 47th Avenue',
#  'North 48th Avenue',
#  'North 48th Drive',
#  'North 48th Street',
#  'North 49th Avenue',
#  'North 4th Avenue',
#  'North 4th Drive',
#  'North 51st Avenue',
#  'North 51st Lane',
#  'North 52nd Avenue',
#  'North 53rd Avenue',
#  'North 54th Street',
#  'North 55th Avenue',
#  'North 56th Street',
#  'North 57th Avenue',
#  'North 57th Drive',
#  'North 58th Avenue',
#  'North 58th Drive',
#  'North 59th Avenue',
#  'North 5th Avenue',
#  'North 5th Drive',
#  'North 5th Street',
#  'North 60th Avenue',
#  'North 61st Avenue',
#  'North 62nd Avenue',
#  'North 63rd Avenue',
#  'North 64th Drive',
#  'North 64th Lane',
#  'North 65th Drive',
#  'North 67th Avenue',
#  'North 67th Lane',
#  'North 68th Avenue',
#  'North 68th Street',
#  'North 69th Avenue',
#  'North 6th Avenue',
#  'North 6th Drive',
#  'North 6th Street',
#  'North 71st Avenue',
#  'North 71st Drive',
#  'North 73rd Street',
#  'North 74th Street',
#  'North 75th Avenue',
#  'North 75th Street',
#  'North 79th Avenue',
#  'North 7th Avenue',
#  'North 7th Drive',
#  'North 7th Street',
#  'North 81st Avenue',
#  'North 83rd Avenue',
#  'North 84th Place',
#  'North 84th Street',
#  'North 85th Avenue',
#  'North 85th Place',
#  'North 87th Avenue',
#  'North 87th Street',
#  'North 89th Avenue',
#  'North 89th Place',
#  'North 8th Avenue',
#  'North 8th Drive',
#  'North 90th Street',
#  'North 91st Avenue',
#  'North 92nd Street',
#  'North 95th Avenue',
#  'North 99th Avenue',
#  'North 9th Avenue',
#  'North Alma School Road',
#  'North Alta Mesa Drive',
#  'North Apache Trail',
#  'North Arcadia Drive',
#  'North Arizona Ave',
#  'North Avondale Boulavard',
#  'North Barnes Parkway',
#  'North Black Canyon Highway',
#  'North Bullard Avenue',
#  'North Camino del Sol',
#  'North Carolina Avenue',
#  'North Cave Creek Road',
#  'North Centennial Way',
#  'North Center Street',
#  'North Central Avenue',
#  'North Charbray Drive',
#  'North Citrus Road',
#  'North Civic Center Plaza',
#  'North Colonnade Way',
#  'North Cortona Drive',
#  'North Cotton Crossing',
#  'North Country Club Drive',
#  'North Coyote Lakes Parkwway',
#  'North Crismon Road',
#  'North Date',
#  'North Del Webb Boulevard',
#  'North Delaware Drive',
#  'North Desert Breeze Boulevard',
#  'North Dobson Road',
#  'North Drinkwater Boulevard',
#  'North Dysart Road',
#  'North El Mirage Road',
#  'North Ellsworth Road',
#  'North Fairway Drive',
#  'North Fayette Drive',
#  'North Federal Street',
#  'North Galvin Parkway',
#  'North Gantzel Road',
#  'North Gilbert Road',
#  'North Grand',
#  'North Greenfield Road',
#  'North Greenway Hayden Loop',
#  'North Hawes Road',
#  'North Hayden Road',
#  'North Higley Road',
#  'North Horne',
#  'North Hunt Drive',
#  'North Idaho Road',
#  'North Ironwood Drive',
#  'North Jackrabbit Trail',
#  'North Kenworthy Road',
#  'North Lake Pleasant Parkway',
#  'North Legend Trail Parkway',
#  'North Lewis',
#  'North Lindsay Road',
#  'North Litchfield Road',
#  'North Longmore Avenue',
#  'North Lyn Rae Drive',
#  'North Main Drive',
#  'North Markdale',
#  'North Marshall Way',
#  'North Maryvale Parkway',
#  'North McClintock Drive',
#  'North Meridian Drive',
#  'North Mesa Drive',
#  'North Metro Park East',
#  'North Mill Avenue',
#  'North Miller Road',
#  'North Mira Bello Road',
#  'North Mockingbird Lane',
#  'North Mountain Road',
#  'North Mule Train Road',
#  'North New Tradition Road',
#  'North Northsight Boulevard',
#  'North Ocotillo Drive',
#  'North Old Bridge Road',
#  'North Palermo Street',
#  'North Palo Verde Drive',
#  'North Papago Drive',
#  'North Paradise Village Parkway South',
#  'North Paradise Village Parkway West',
#  'North Parkview Place',
#  'North Pasadena',
#  'North Pecan Creek Drive',
#  'North Pima',
#  'North Pima Road',
#  'North Pima Street',
#  'North Plaza Drive',
#  'North Power Road',
#  'North Project Drive',
#  'North R H Johnson Boulevard',
#  'North Recker Road',
#  'North Red Mountain',
#  'North Reems Road',
#  'North Saguaro Drive',
#  'North Scottsdale Healthcare Drive',
#  'North Scottsdale Road',
#  'North Signal Butte Road',
#  'North Simonton Boulevard',
#  'North Spanish Garden Drive',
#  'North Stapley Drive',
#  'North Star Ridge Drive',
#  'North Stardust Boulevard',
#  'North Sterling Street',
#  'North Sun Lakes Boulevard',
#  'North Sunrise Point',
#  'North Sunvalley Boulevard',
#  'North Sycamore',
#  'North Taliesin',
#  'North Tatum Boulevard',
#  'North Tatum Ranch Drive',
#  'North Thompson Peak Parkway',
#  'North Thunderbird Drive',
#  'North Val Vista Drive',
#  'North Via Paseo del Sur',
#  'North Village Lane',
#  'North Vista Road',
#  'North Warner Drive',
#  'North Wells Fargo Avenue',
#  'North Westwood',
#  'North Zanjero Boulevard',
#  'North Zephyr Drive',
#  'Northwest Grand Avenue',
#  'S Buena Vista Ave',
#  'S Central Ave',
#  'S Farmer Ave',
#  'San Marcos Place',
#  'South 164th Street',
#  'South 19th Avenue',
#  'South 1st Street',
#  'South 27th Avenue',
#  'South 2nd Street',
#  'South 32nd Street',
#  'South 35th Avenue',
#  'South 3rd Avenue',
#  'South 40th Street',
#  'South 44th Street',
#  'South 48th Street',
#  'South 4th Avenue',
#  'South 4th Street',
#  'South 50th Street',
#  'South 51st Avenue',
#  'South 7th Street',
#  'South 83rd Place',
#  'South 96th Street',
#  'South Adora Boulevard',
#  'South All American Way',
#  'South Allesandro Court',
#  'South Alma School Road',
#  'South Apache Street',
#  'South Arizona Avenue',
#  'South Ash Avenue',
#  'South Avondale Boulevard',
#  'South Cactus Road',
#  'South Cady Mall',
#  'South Carmalita Court',
#  'South Carriage Lane',
#  'South Central Avenue',
#  'South Cheshire',
#  'South Chestnut',
#  'South Coconino Drive',
#  'South Colt Road',
#  'South Cooper Road',
#  'South Country Club Drive',
#  'South Crimson Road',
#  'South Crismon Road',
#  'South Delaware Drive',
#  'South Dobson',
#  'South Dobson Road',
#  'South Ellsworth Loop Road',
#  'South Ellsworth Road',
#  'South Emerson',
#  'South Eucalyptus Place',
#  'South Extension Road',
#  'South Forest Avenue',
#  'South Forest Mall',
#  'South Franks Place',
#  'South Gilbert Road',
#  'South Girard Street',
#  'South Goldfield Road',
#  'South Golf Club Drive',
#  'South Grand Drive',
#  'South Greenfield Road',
#  'South Hall',
#  'South Hemet Street',
#  'South Higley Road',
#  'South Horne Street',
#  'South Idaho Road',
#  'South Inez Court',
#  'South Ironwood Drive',
#  'South Joshua Tree Lane',
#  'South Kerby Way',
#  'South Kings Ranch Road',
#  'South Kyrene Road',
#  'South Lakeshore Drive',
#  'South Lazona Drive',
#  'South Lindsay Road',
#  'South Longmore',
#  'South Longmore Ave',
#  'South Maple Avenue',
#  'South Maricopa Road',
#  'South Mariposa Drive',
#  'South Mariposa Road',
#  'South Market Street',
#  'South McClintock Drive',
#  'South Meridian Drive',
#  'South Mill Avenue',
#  'South Miller Road',
#  'South Mountain Road',
#  'South Mountain View Road',
#  'South MountainBrook Drive',
#  'South Palomar Court',
#  'South Phelps Drive',
#  'South Plaza Drive',
#  'South Ponderosa Drive',
#  'South Power Road',
#  'South Price Road',
#  'South Priest Drive',
#  'South Revere Circle',
#  'South Roosevelt Street',
#  'South Rural Road',
#  'South Ryan Court',
#  'South San Marcos Drive',
#  'South San Miguel Avenue',
#  'South Signal Butte Road',
#  'South Sirrine',
#  'South Sirrine Avenue',
#  'South Soboba Street',
#  'South Sossaman Road',
#  'South Spectrum Boulevard',
#  'South Spectrum Way',
#  'South Spruce',
#  'South Stapley Drive',
#  'South Starr Road',
#  'South Sunnyvale',
#  'South Tatum Lane',
#  'South Terrace Road',
#  'South Thunderbird Drive',
#  'South Tomahawk Road',
#  'South Val Vista Drive',
#  'South Valencia',
#  'South Village Boulevard',
#  'South Vista Road',
#  'South Watson Road',
#  'South Westwood',
#  'South Winchester Road',
#  'South de Niza Road',
#  'W 18th St',
#  'W 19th Street',
#  'W Blackstone Drive',
#  'W McNeil St',
#  'W. Camelback',
#  'W. North Loop Road',
#  'W. Vineyard Ave',
#  'Weber Road',
#  'West 10th Place',
#  'West 13th Place',
#  'West 16th Avenue',
#  'West 1st Street',
#  'West 37th Avenue',
#  'West 4th Avenue',
#  'West 5th Street',
#  'West 6th Street',
#  'West 8th Street',
#  'West 9th Place',
#  'West Acoma Road',
#  'West Adams Street',
#  'West Albert Lane',
#  'West Anderson Avenue',
#  'West Anderson Drive',
#  'West Angela Drive',
#  'West Apache Trail',
#  'West Arrowhead Towne Center',
#  'West Baseline Avenue',
#  'West Baseline Road',
#  'West Bass Pro Drive',
#  'West Beardsley Road',
#  'West Bell Road',
#  'West Beloat Road',
#  'West Bethany Home Road',
#  'West Betty Elyse Lane',
#  'West Bluefield Avenue',
#  'West Boston Street',
#  'West Broadway Avenue',
#  'West Broadway Road',
#  'West Brown Road',
#  'West Brown Street',
#  'West Buchanan Street',
#  'West Buckeye Road',
#  'West Butler Drive',
#  'West Cabela Drive',
#  'West Cactus Road',
#  'West Camelback Road',
#  'West Camino del Sol',
#  'West Campbell Avenue',
#  'West Campo Bello Drive',
#  'West Cardinals Drive',
#  'West Carefree Highway',
#  'West Carver Road',
#  'West Catalina Drive',
#  'West Celebrate Life Way',
#  'West Chandler Boulevard',
#  'West Charleston Avenue',
#  'West Cheryl Drive',
#  'West Cholla Street',
#  'West Clarendon Avenue',
#  'West Colter Street',
#  'West Cornell Drive',
#  'West Cortez Street',
#  'West Culver Street',
#  'West Dailey Street',
#  'West Danbury Road',
#  'West Dealer Avenue',
#  'West Deer Valley Drive',
#  'West Deer Valley Road',
#  'West Denton Lane',
#  'West Desert Cove Avenue',
#  'West Desert Cove Road',
#  'West Desert Vista Trail',
#  'West Dunlap Avenue',
#  'West Durango Street',
#  'West Elliot Road',
#  'West Empire Road',
#  'West Encanto Boulevard',
#  'West Eugie Avenue',
#  'West Fairway Drive',
#  'West Fellars Drive',
#  'West Florentino Street',
#  'West Foxfire Drive',
#  'West Frank Avenue',
#  'West Frier Drive',
#  'West Galveston Street',
#  'West Geronimo Place',
#  'West Gibraltar Lane',
#  'West Gibson Lane',
#  'West Glendale Avenue',
#  'West Glenn Drive',
#  'West Golden Lane',
#  'West Goldwater Ridge Drive',
#  'West Grand Avenue',
#  'West Grandview Road',
#  'West Granite Valley Drive',
#  'West Greenbriar Drive',
#  'West Greenway Road',
#  'West Grove Ave',
#  'West Grove Avenue',
#  'West Grovers Avenue',
#  'West Guadalupe Road',
#  'West Hadley Street',
#  'West Halstead Drive',
#  'West Hanna Lane',
#  'West Happy Valley Rd',
#  'West Happy Valley Road',
#  'West Happy Vally Rd.',
#  'West Harrison Street',
#  'West Hartford Avenue',
#  'West Hartford Drive',
#  'West Hatcher Road',
#  'West Hatfield Road',
#  'West Helen Lane',
#  'West Helena Drive',
#  'West Hillcrest Boulevard',
#  'West Hunt Highway',
#  'West Ikea Way',
#  'West Indian School Road',
#  'West Isabella Avenue',
#  'West Ivyglen Street',
#  'West Jackson Street',
#  'West Jefferson Street',
#  'West Joan de Arc Avenue',
#  'West Kathleen Road',
#  'West Keim Drive',
#  'West Kelton Lane',
#  'West Kings Avenue',
#  'West La Jolla Drive',
#  'West Lake Pleasant Parkway',
#  'West Lamar Road',
#  'West Latham Street',
#  'West Lawrence Road',
#  'West Libby Street',
#  'West Lincoln Street',
#  'West Ludlow Drive',
#  'West Madison Street',
#  'West Main Street',
#  'West Marconi Avenue',
#  'West Mariners Way',
#  'West Mariposa Street',
#  'West Market Street',
#  'West Marlette Avenue',
#  'West Marshall Avenue',
#  'West Maryland Avenue',
#  'West McDowell Road',
#  'West McKellips Road',
#  'West McLellan Road',
#  'West Medina Avenue',
#  'West Meeker Boulevard',
#  'West Melody Avenue',
#  'West Mesquite Street',
#  'West Michelle Drive',
#  'West Michigan Avenue',
#  'West Minnezona Avenue',
#  'West Mission Lane',
#  'West Missouri Avenue',
#  'West Mohave Street',
#  'West Mohawk Lane',
#  'West Monroe Street',
#  'West Montecito Avenue',
#  'West Mountain View Boulevard',
#  'West Mountain View Road',
#  'West Muriel Drive',
#  'West Myrtle Avenue',
#  'West Nancy Road',
#  'West North Lane',
#  'West Northern Avenue',
#  'West Ocotillo Road',
#  'West Olive Avenue',
#  'West One Payment Way',
#  'West Oraibi Drive',
#  'West Orangewood Avenue',
#  'West Osborn Road',
#  'West Papago Freeway',
#  'West Parkwood Drive',
#  'West Parkwood Place',
#  'West Pasadena Avenue',
#  'West Pebble Creek Parkway',
#  'West Peoria Avenue',
#  'West Peralta Avenue',
#  'West Phelps Road',
#  'West Pierson Street',
#  'West Pinnacle Peak Road',
#  'West Portland Street',
#  'West Quail Avenue',
#  'West Queen Creek Road',
#  'West R H Johnson Boulevard',
#  'West Ray Road',
#  'West Rio Salado Parkway',
#  'West Riverview Auto Drive',
#  'West Roosevelt Street',
#  'West Rose Garden Lane',
#  'West Rovey Avenue',
#  'West Royal Palm Road',
#  'West Ruby Drive',
#  'West Saint John Road',
#  'West San Tan Heights Boulevard',
#  'West San Tan Hills Drive',
#  'West Sandridge Drive',
#  'West Shangri la Road',
#  'West Shawnee Drive',
#  'West Sierra Vista Drive',
#  'West Sleepy Ranch Road',
#  'West Smoketree Street',
#  'West Smokey Drive',
#  'West Southern Avenue',
#  'West Spanish Garden Drive',
#  'West Summit Place',
#  'West Superstition Boulevard',
#  'West Sweetwater Avenue',
#  'West Tepee Street',
#  'West Thomas Road',
#  'West Thompson Ranch Road',
#  'West Thunderbird Boulevard',
#  'West Thunderbird Road',
#  'West Tierra Buena Lane',
#  'West Townley Avenue',
#  'West Turney Avenue',
#  'West Union Hills Drive',
#  'West University Drive',
#  'West Utopia Road',
#  'West Van Buren Street',
#  'West Varney Road',
#  'West Vernon Avenue',
#  'West Villa Maria Drive',
#  'West Villa Rita Drive',
#  'West Villa Theresa Drive',
#  'West Virginia Avenue',
#  'West Wagoner Road',
#  'West Washington Street',
#  'West Westar Drive',
#  'West Wild Horse Pass Boulevard',
#  'West Wilshire Drive',
#  'West Windsor Boulevard',
#  'West Yorkshire Drive',
#  'West Yuma Road',
#  'West del Rio Street',
#  'Windsor'}

# %%
import string
conventions = [['West','W'],['North','N'],["South","S"],['East','E'],['Street',"St"],["Road","Rd"],["Avenue","Av","Ave"],
                            ["Place","Pl"],["Boulevard","Blvd"],["Trail","Tr"],["Place","Pl"],["Highway","Hwy","Hw","Hy"],
                            ["Parkway","Pkwy","Pw"]]
num_conventions = len(conventions)

def conv_street(street_name):
    split_up = street_name.split(" ")
    for i in range(len(split_up)):
        for j in range(num_conventions):
            #Strip punctuation and compare to naming conventions list
            if split_up[i].translate(None, string.punctuation) in conventions[j]:
                split_up[i] = conventions[j][0]
    #piece the street string back together with the change
    whole = ' '.join(c for c in split_up)
    return whole

def conv_df(df):
    #This function takes a pandas dataframe which contains a 'key' column with 'street' values and 
    # converts the values according to the conv_street function
    for i in range(len(df)):
        if df.loc[i,'key'] == 'street':
            df.loc[i,'value'] = conv_street(df.loc[i,'value'])
    return df

# %%
nodes_tags = conv_df(nodes_tags)
ways_tags = conv_df(ways_tags)
# Out:
# 0
# 10000
# 20000
# 30000
# 40000
# 50000
# 60000
# 70000
# 80000
# 90000
# 100000
# 110000
# 120000
# 130000
# 140000
# 150000
# 160000
# 170000
# 180000
# 190000
# 200000
# 210000
# 220000
# 230000
# 240000
# 250000
# 260000
# 270000
# 280000
# 0
# 10000
# 20000
# 30000
# 40000
# 50000
# 60000
# 70000
# 80000
# 90000
# 100000
# 110000
# 120000
# 130000
# 140000
# 150000
# 160000
# 170000
# 180000
# 190000
# 200000
# 210000
# 220000
# 230000
# 240000
# 250000
# 260000
# 270000
# 280000
# 290000
# 300000
# 310000
# 320000
# 330000
# 340000
# 350000
# 360000
# 370000
# 380000
# 390000
# 400000
# 410000
# 420000
# 430000
# 440000
# 450000
# 460000
# 470000
# 480000
# 490000
# 500000
# 510000
# 520000
# 530000
# 540000
# 550000
# 560000
# 570000
# 580000
# 590000
# 600000
# 610000
# 620000
# 630000
# 640000
# 650000
# 660000
# 670000
# 680000
# 690000
# 700000
# 710000
# 720000
# 730000
# 740000
# 750000
# 760000
# 770000
# 780000
# 790000
# 800000
# 810000
# 820000
# 830000
# 840000
# 850000
# 860000
# 870000
# 880000
# 890000
# 900000
# 910000
# 920000
# 930000
# 940000
# 950000
# 960000
# 970000
# 980000
# 990000
# 1000000
# 1010000
# 1020000
# 1030000
# 1040000
# 1050000
# 1060000
# 1070000
# 1080000
# 1090000
# 1100000
# 1110000
# 1120000
# 1130000
# 1140000
# 1150000
# 1160000
# 1170000
# 1180000
# 1190000
# 1200000
# 1210000
# 1220000
# 1230000
# 1240000
# 1250000
# 1260000
# 1270000
# 1280000
# 1290000
# 1300000
# 1310000
# 1320000
# 1330000
# 1340000
# 1350000
# 1360000
# 1370000
# 1380000
# 1390000
# 1400000
# 1410000
# 1420000
# 1430000
# 1440000
# 1450000
# 1460000
# 1470000
# 1480000
# 1490000
# 1500000
# 1510000
# 1520000
# 1530000
# 1540000
# 1550000
# 1560000
# 1570000
# 1580000
# 1590000
# 1600000
# 1610000
# 1620000
# 1630000
# 1640000
# 1650000
# 1660000
# 1670000
# 1680000
# 1690000
# 1700000
# 1710000
# 1720000
# 1730000

# %% [markdown]
# ## Create uniformity in the 'key' = 'state' values that refer to an address

# %%
AZ_reps = ['A', 'AS', 'AZ', 'AZ (Arizona)', 'AZZ', 'Arizona', 'Az', 'az']
for i in range(len(ways_tags)):
    if ways_tags.loc[i,'key'] == 'state' and ways_tags.loc[i,'type'] == 'addr' and ways_tags.loc[i,'value'] in AZ_reps:
        ways_tags.loc[i,'value'] = 'AZ'

        
for i in range(len(nodes_tags)):
    if nodes_tags.loc[i,'key'] == 'state' and nodes_tags.loc[i,'type'] == 'addr' and nodes_tags.loc[i,'value'] in AZ_reps:
        nodes_tags.loc[i,'value'] = 'AZ'

# %% [markdown]
# ## Check for what inconsistencies may exist in the 'key'='county' data in *_tags data

# %%
set(nodes_tags[nodes_tags['key'] == 'county']['value'])
# Out:
# {'Maricopa'}

# %%
set(ways_tags[ways_tags['key'] == 'county']['value'])
# Out:
# {'Gila, AZ',
#  'Maricopa',
#  'Maricopa, AZ',
#  'Maricopa, AZ:Yavapai, AZ',
#  'Pinal, AZ'}

# %% [markdown]
# #### This will be easy enought to convert to just contain the county name and not the state abbreviation which should  be in another field for a database.  It will just take some time.

# %%
for i in range(len(ways_tags)):
    if ways_tags.loc[i,'key'] == 'county':
        split = ways_tags.loc[i,'value'].split(",")
        if 'Maricopa' == split[0]:
            ways_tags.loc[i,'county'] = 'Maricopa'
        elif 'Gila' == split[0]:
            ways_tags.loc[i,'county'] = 'Gila'
        elif 'Pinal' == split[0]:
            ways_tags.loc[i,'county'] = 'Pinal'
    if i % 1000 == 0:
        print(i)
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
